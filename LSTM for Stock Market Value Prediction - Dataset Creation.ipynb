# %%
import pandas as pd

dataset=pd.read_csv('005930.KS.csv').values
open_value=dataset[:,1]
print(open_value[:5])

open_value=open_value.reshape(-1,1) #convering into a column vector
print(open_value[:5])

print(open_value.shape)
# Out:
# [47020 45640 46380 46220 46460]
# [[47020]
#  [45640]
#  [46380]
#  [46220]
#  [46460]]
# (1225, 1)

# %%
from matplotlib import pyplot as plt

plt.plot(open_value)
plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler(feature_range=(0,1))
scaled_open_value=scaler.fit_transform(open_value)

print(open_value[:5].T)
print(scaled_open_value[:5].T)
# Out:
# [[47020 45640 46380 46220 46460]]
# [[0.18107852 0.15496689 0.16896878 0.16594134 0.1704825 ]]

# %%
data=[]
target=[]

for i in range(50,open_value.shape[0]):
    data.append(scaled_open_value[i-50:i])
    target.append(scaled_open_value[i])

# %%
import numpy as np

data_np=np.array(data)
target_np=np.array(target)

print(data_np.shape)
print(target_np.shape)
# Out:
# (1175, 50, 1)
# (1175, 1)

# %%
np.save('data',data)
np.save('target',target)
